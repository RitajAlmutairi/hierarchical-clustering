# %%
#RITAJ M. ALMUTAIRI - 2006532

# driver_hierarchical.py
import create_dataset_sklearn
import hierarchical
import matplotlib.pyplot as plt

# (1) generate data
nsample = 200

case = "blobs"
X = create_dataset_sklearn.create_dataset(nsample,case)

# (2) create model - instance of hierarchical class object
model = hierarchical.hierarchical()

# (3) perform clustering
model.fit(X)
print("Time fit: {}".format(model.time_fit))

# (4) plot results
nlevel = -3

# plot initial data
model.plot_cluster(nlevel=0, title="Dataset: " + case, xlabel="Feature x0", ylabel="Feature x1")

# plot final clusters (at level with 3 clusters)
model.plot_cluster(nlevel=nlevel, title="Hierarchical Clustering Dataset: " + case, 
xlabel="Feature x0", ylabel="Feature x1")

# plot animation (to level with 3 clusters)
ani = model.plot_cluster_animation(nlevel=nlevel,interval=100,title="Hierarchical Clustering Dataset: "+case,
xlabel="Feature x0", ylabel="Feature x1")
plt.show()
# Out:
# Case: blobs  Number of dimensions: 2 Number of Samples: 200
# Time fit: 7.3859381675720215

# %%
import create_dataset_sklearn
import hierarchical
import matplotlib.pyplot as plt

# (1) generate data
nsample = 200

case = "varied_blobs2"
X = create_dataset_sklearn.create_dataset(nsample,case)

# (2) create model - instance of hierarchical class object
model = hierarchical.hierarchical()

# (3) perform clustering
model.fit(X)
print("Time fit: {}".format(model.time_fit))

# (4) plot results
nlevel = -3

# plot initial data
model.plot_cluster(nlevel=0, title="Dataset: " + case, xlabel="Feature x0", ylabel="Feature x1")

# plot final clusters (at level with 3 clusters)
model.plot_cluster(nlevel=nlevel, title="Hierarchical Clustering Dataset: " + case, 
xlabel="Feature x0", ylabel="Feature x1")

# plot animation (to level with 3 clusters)
ani = model.plot_cluster_animation(nlevel=nlevel,interval=100,title="Hierarchical Clustering Dataset: "+case,
xlabel="Feature x0", ylabel="Feature x1")
plt.show()
# Out:
# Case: varied_blobs2  Number of dimensions: 2 Number of Samples: 200
# Time fit: 7.315604209899902

# %%
import create_dataset_sklearn
import hierarchical
import matplotlib.pyplot as plt

# (1) generate data
nsample = 200

case = "aniso"
X = create_dataset_sklearn.create_dataset(nsample,case)

# (2) create model - instance of hierarchical class object
model = hierarchical.hierarchical()

# (3) perform clustering
model.fit(X)
print("Time fit: {}".format(model.time_fit))

# (4) plot results
nlevel = -3

# plot initial data
model.plot_cluster(nlevel=0, title="Dataset: " + case, xlabel="Feature x0", ylabel="Feature x1")

# plot final clusters (at level with 3 clusters)
model.plot_cluster(nlevel=nlevel, title="Hierarchical Clustering Dataset: " + case, 
xlabel="Feature x0", ylabel="Feature x1")

# plot animation (to level with 3 clusters)
ani = model.plot_cluster_animation(nlevel=nlevel,interval=100,title="Hierarchical Clustering Dataset: "+case,
xlabel="Feature x0", ylabel="Feature x1")
plt.show()
# Out:
# Case: aniso  Number of dimensions: 2 Number of Samples: 200
# Time fit: 7.2983996868133545

# %%
import create_dataset_sklearn
import hierarchical
import matplotlib.pyplot as plt

# (1) generate data
nsample = 200

case = "noisy_moons"
X = create_dataset_sklearn.create_dataset(nsample,case)

# (2) create model - instance of hierarchical class object
model = hierarchical.hierarchical()

# (3) perform clustering
model.fit(X)
print("Time fit: {}".format(model.time_fit))

# (4) plot results
nlevel = 2

# plot initial data
model.plot_cluster(nlevel=0, title="Dataset: " + case, xlabel="Feature x0", ylabel="Feature x1")

# plot final clusters (at level with 3 clusters)
model.plot_cluster(nlevel=nlevel, title="Hierarchical Clustering Dataset: " + case, 
xlabel="Feature x0", ylabel="Feature x1")

# plot animation (to level with 3 clusters)
ani = model.plot_cluster_animation(nlevel=nlevel,interval=100,title="Hierarchical Clustering Dataset: "+case,
xlabel="Feature x0", ylabel="Feature x1")
plt.show()
# Out:
# Case: noisy_moons  Number of dimensions: 2 Number of Samples: 200
# Time fit: 7.293712377548218

# %%
import create_dataset_sklearn
import hierarchical
import matplotlib.pyplot as plt

# (1) generate data
nsample = 200

case = "noisy_circles"
X = create_dataset_sklearn.create_dataset(nsample,case)

# (2) create model - instance of hierarchical class object
model = hierarchical.hierarchical()

# (3) perform clustering
model.fit(X)
print("Time fit: {}".format(model.time_fit))

# (4) plot results
nlevel = 2

# plot initial data
model.plot_cluster(nlevel=0, title="Dataset: " + case, xlabel="Feature x0", ylabel="Feature x1")

# plot final clusters (at level with 3 clusters)
model.plot_cluster(nlevel=nlevel, title="Hierarchical Clustering Dataset: " + case, 
xlabel="Feature x0", ylabel="Feature x1")

# plot animation (to level with 3 clusters)
ani = model.plot_cluster_animation(nlevel=nlevel,interval=100,title="Hierarchical Clustering Dataset: "+case,
xlabel="Feature x0", ylabel="Feature x1")
plt.show()
# Out:
# Case: noisy_circles  Number of dimensions: 2 Number of Samples: 200
# Time fit: 7.629321098327637
