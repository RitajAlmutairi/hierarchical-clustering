# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/countries-continents/countries_continents.csv

# %% [markdown]
# # RITAJ M. ALMUTAIRI - 2006532 - LAB 3 Q2

# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import matplotlib
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
#Storing and reading the data.

fileName = "/kaggle/input/countries-continents/countries_continents.csv"

df = pd.read_csv(fileName)
df.head()
# Out:
#        Country  Longitude   Latitude      Continent
# 0        Aruba -69.982677  12.520880  North America
# 1  Afghanistan  66.004734  33.835231           Asia
# 2       Angola  17.537368 -12.293361         Africa
# 3     Anguilla -63.064989  18.223959  North America
# 4      Albania  20.049834  41.142450         Europe

# %%
df.dropna()

location = df[['Longitude','Latitude']]

location
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# **Q2.2**

# %%
#Array of colors only for plotting the data
colors=['pink','lightseagreen','lightgreen','orange','lightcoral','lightblue']

# %% [markdown]
# 1. **--SINGLE--**

# %%
single_linkage = AgglomerativeClustering(n_clusters=7, linkage = 'single')
s_Linked = single_linkage.fit_predict(location)

df['linkage']= s_Linked

# %%
#Plotting the data
plt.figure(figsize = (7,7))

#Scattter the data
plt.scatter(df['Longitude'], df['Latitude'], c = df['linkage'],cmap=matplotlib.colors.ListedColormap(colors),s=20)

plt.title('single linkage')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %% [markdown]
# 2. **--COMPLETE--**

# %%
#Aggolomerative object to apply complete method , i decided 7 clusters because of the reslutes of Lab2 
complete_linkage = AgglomerativeClustering(n_clusters=7, linkage = 'complete')
#Fit the model
comp_Linked = complete_linkage.fit_predict(location)

df['linkage']= comp_Linked

# %%
#Plotting the data
plt.figure(figsize = (7,7))

#Scattter the data
plt.scatter(df['Longitude'], df['Latitude'], c = df['linkage'],cmap=matplotlib.colors.ListedColormap(colors),s=20)

plt.title('Complete linkage')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %% [markdown]
# 3. **--AVERAGE--**

# %%
#Aggolomerative object to apply average method , i decided 7 clusters because of the reslutes of Lab2 

average_linkage = AgglomerativeClustering(n_clusters=7, linkage = 'average')

#Fit the model
average = average_linkage.fit_predict(location)

df['linkage']= average

# %%
#Plotting the data
plt.figure(figsize = (7,7))

#Scattter the data
plt.scatter(df['Longitude'], df['Latitude'], c = df['linkage'],cmap=matplotlib.colors.ListedColormap(colors),s=20)

plt.title('Average Linkage')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %% [markdown]
# 4. **--WARD--**

# %%
#Aggolomerative object to apply ward method , i decided 7 clusters because of the reslutes of Lab2 

ward_linkage = AgglomerativeClustering(n_clusters=7, linkage = 'ward')

#Fit the model
ward = ward_linkage.fit_predict(location)

df['linkage']= ward

# %%
#Plotting the data
plt.figure(figsize = (7,7))

#Scattter the data
plt.scatter(df['Longitude'], df['Latitude'], c = df['linkage'],cmap=matplotlib.colors.ListedColormap(colors),s=20)

plt.title('Ward Linkage')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %% [markdown]
# **Q2.3: Dendogram**

# %%
#Plotting the dendogram
sigle_linked = linkage(df[['Longitude','Latitude']], method = 'single')

plt.figure(1,figsize = (40,40))

dendrogram(sigle_linked,
           orientation='top',
           distance_sort='descending')

plt.title('Single Linkage',fontsize=30)
plt.xlabel('locations',fontsize = 30)
plt.ylabel('Euclidean distances',fontsize = 30)

plt.show()

# %% [markdown]
# **I chose to cut the dendogram at y= 30**

# %%
#Single Linkage after applying the cut

sigle_linked = linkage(df[['Longitude','Latitude']], method = 'single')

plt.figure(1,figsize = (40,40))

dendrogram(sigle_linked,
           orientation='top',
           distance_sort='descending')

plt.axhline(y= 25, color='b', linestyle='--')


plt.title('Single Linkage',fontsize=30)
plt.xlabel('locations',fontsize = 30)
plt.ylabel('Euclidean distances',fontsize = 30)

plt.show()

# %% [markdown]
# **I got 5 clusters from the single linkage.**

# %% [markdown]
# **Complete Linkage**

# %%
#Complete Linkage before applying the cut

complete_linked = linkage(df[['Longitude','Latitude']], method = 'complete')

plt.figure(1,figsize = (40,40))

dendrogram(complete_linked,
           orientation='top',
           distance_sort='descending')

plt.title('Complete Linkage',fontsize=30)
plt.xlabel('locations',fontsize = 30)
plt.ylabel('Euclidean distances',fontsize = 30)

plt.show()

# %%
#Complete Linkage after applying the cut

complete_linked = linkage(df[['Longitude','Latitude']], method = 'complete')

plt.figure(1,figsize = (40,40))

dendrogram(complete_linked,
           orientation='top',
           distance_sort='descending')

plt.axhline(y= 110, color='b', linestyle='--')


plt.title('Complete Linkage',fontsize=30)
plt.xlabel('locations',fontsize = 30)
plt.ylabel('Euclidean distances',fontsize = 30)

plt.show()

# %% [markdown]
# **Averege Linkage**

# %%
#Average Linkage before applying the cut

avg_linked = linkage(df[['Longitude','Latitude']], method = 'average')

plt.figure(1,figsize = (40,40))

dendrogram(avg_linked,
           orientation='top',
           distance_sort='descending')

plt.title('Average Linkage',fontsize=30)
plt.xlabel('locations',fontsize = 30)
plt.ylabel('Euclidean distances',fontsize = 30)

plt.show()

# %%
#Average Linkage before applying the cut

avg_linked = linkage(df[['Longitude','Latitude']], method = 'average')

plt.figure(1,figsize = (40,40))

dendrogram(avg_linked,
           orientation='top',
           distance_sort='descending')

plt.axhline(y= 80, color='b', linestyle='--')

plt.title('Average Linkage',fontsize=30)
plt.xlabel('locations',fontsize = 30)
plt.ylabel('Euclidean distances',fontsize = 30)

plt.show()

# %% [markdown]
# **I got 5 clusters by applying average linkage.**

# %%
#Ward Linkage before applying the cut

ward_linked = linkage(df[['Longitude','Latitude']], method = 'ward')

plt.figure(1,figsize = (40,40))

dendrogram(ward_linked,
           orientation='top',
           distance_sort='descending')


plt.title('Ward Linkage',fontsize=30)
plt.xlabel('location',fontsize = 30)
plt.ylabel('Euclidean distance',fontsize = 30)

plt.show()

# %%
#Ward Linkage before applying the cut

ward_linked = linkage(df[['Longitude','Latitude']], method = 'ward')

plt.figure(1,figsize = (40,40))

dendrogram(ward_linked,
           orientation='top',
           distance_sort='descending')

plt.axhline(y= 200, color='b', linestyle='--')

plt.title('Ward Linkage',fontsize=30)
plt.xlabel('location',fontsize = 30)
plt.ylabel('Euclidean distance',fontsize = 30)

plt.show()

# %% [markdown]
# **I think the ward is the best one, because the dendogram is too clear to see an to apply the cut. Plus, in lab2 I got 7 clusters so, I think ward method is more accurate.**

# %% [markdown]
# **Q2.5 Comparing with the actual clusters.**

# %%
from sklearn.cluster import AgglomerativeClustering

model = AgglomerativeClustering(n_clusters=7, affinity='euclidean')
model.fit(df[['Longitude','Latitude']])

df['HR_labels']=model.labels_

# %%
# Plotting resulting clusters
plt.figure(figsize=(5,5))
plt.scatter(df[['Longitude']],df[['Latitude']], c=df['HR_labels'], cmap=matplotlib.colors.ListedColormap(colors),s=15)

plt.title('Actual Clustering')

plt.xlabel('Longitude',fontsize=10)
plt.ylabel('Latitude',fontsize=10)
plt.show()

# %%
# Plot the identified clusters and compare it with the 4 metrics.
fig,axs = plt.subplots(nrows=3,ncols=2,figsize = (10,10))

axs[0,0].scatter(df[['Longitude']],df[['Latitude']], c=df['HR_labels'], cmap=matplotlib.colors.ListedColormap(colors),s=15)
axs[0,0].set_title("Actual Clustering",fontsize = 15)

#Dont show the fig in the axis(0,1)
fig.delaxes(axs[0][1])
#Single Linkage
df['linkage']= single

axs[1,0].scatter(df[["Longitude"]], df[["Latitude"]],c= df['linkage'], cmap=matplotlib.colors.ListedColormap(colors), s=15);
axs[1,0].set_title("Single linkage",fontsize = 15)

#Complete Linkage
df['linkage']= comp_Linked

axs[1,1].scatter(df[["Longitude"]] ,df[["Latitude"]], c= df['linkage'], cmap=matplotlib.colors.ListedColormap(colors), s=15);
axs[1,1].set_title("Complete linkage",fontsize = 15)

#Average Linkage
df['linkage']= average

axs[2,0].scatter(df[["Longitude"]], df[["Latitude"]], c= df['linkage'], cmap=matplotlib.colors.ListedColormap(colors), s=15);
axs[2,0].set_title("Average linkage",fontsize = 15)

#Ward Linkage
df['linkage']= ward

axs[2,1].scatter(df[["Longitude"]], df[["Latitude"]], c= df['linkage'], cmap=matplotlib.colors.ListedColormap(colors), s=15);
axs[2,1].set_title("Ward linkage",fontsize = 15)

#Set space between the subgraphs.
fig.tight_layout(pad=5.0)

# %% [markdown]
# **It is obvious that the ward linkage is more accurate.**
